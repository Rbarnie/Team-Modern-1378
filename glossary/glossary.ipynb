# %% [markdown]
# ITAI 1378<br>
# Dr Brown<br>
# Mid-Term Glossary<br>
# Adam Blank<br>
# Rashon Barney<br>
# Anthony Dinh<br>

# %% [markdown]
# Ground Truth: in machine learning, the ground truth is a known output, such as if you have a picture of a storm cloud, the ground truth would be the storm cloud.  By estabilishing the ground truth and training the algorithm against that known, it the algorithm becomes more accurate.
